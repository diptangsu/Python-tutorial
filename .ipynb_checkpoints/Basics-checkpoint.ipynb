# %% [markdown]
# # <font color="green">Hello World</font>

# %% [markdown]
# <hr>

# %% [markdown]
# <img src="img/java-logo.png" height=70 width=70 align="left">
# ## Java

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ```java
# class HelloWorld
# {
#     public static void main(String args[])
#     {
#         System.out.println("Hello World");
#     }
# }```

# %% [markdown]
# <hr>

# %% [markdown]
# <img src="img/cpp-logo.png" height=70 width=70 align="left">
# ## C++

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ```cpp
# #include<iostream>
# using namespace std;
# int main(int argc, char *argv[])
# {
#     cout<<"Hello World"<<endl;
#
#     return 0;
# }
# ```

# %% [markdown]
# <hr>

# %% [markdown]
# <img src="img/c-logo.png" height=70 width=70 align="left">
# ## C

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ```c
# #include<stdio.h>
# int main(int argc, char *argv[])
# {
#     printf("Hello World\n");
#
#     return 0;
# }```

# %% [markdown]
# <hr>

# %% [markdown]
# <img src="img/python-logo.png" height=70 width=70 align="left">
# ## Python

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# <hr>

# %% [markdown]
# ## Syntax
# * No semicolons at the end of statements <font color="red" size=5>;</font>
# * No braces <font color="red">{ ... }</font>
# * Indentation (whitespace) is used to define scope, or blocks of code
# * A block of python code begins with a colon <font color="red" size=5>:</font>

# %% [markdown]
# <hr>

# %% [markdown]
# ## Comments

# %%
# This is a single line comment
print('Hello World')
# Out:
# Hello World

# %%
'''
This is a multiline string
used as multiline comments
or docstrings
Python ignores a string which
isn't assigned to a variable
'''
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# <hr>

# %% [markdown]
# ## Variables
#
# ### Rules for naming Python variables:
# - Must start with a letter or an underscore character.
# - Cannot start with a number.
# - Can only contain alpha-numeric characters and underscores (A-Z, a-z, 0-9, and _ ).
# - Case-sensitive (`abc`, `Abc` and `ABC` different variables).

# %%
name = 'Diptangsu Goswami'
age = 21
height = 182.88  # cm

# %% [markdown]
# - You can't declare variables in Python.
# - A variable gets created when a value is assigned to it.
# - Python is a <font color="blue">dynamically typed</font> language.

# %%
print(name)
print(age)
print(height)
print()
print(f'{name} is {age} years old and is {height} centimeters tall')
# Out:
# Diptangsu Goswami
# 21
# 182.88
#
# Diptangsu Goswami is 21 years old and is 182.88 centimeters tall

# %%
1a = 100
# Out:
#   File "<ipython-input-10-db21238de55a>", line 1
#     1a = 100
#      ^
# SyntaxError: invalid syntax

# %%
name$ = 'dip'
# Out:
#   File "<ipython-input-11-40b367985cd2>", line 1
#     name$ = 'dip'
#         ^
# SyntaxError: invalid syntax

# %%
x, y, z = 10, 20, 30  # This syntax is called tuple unpacking
name, college = 'Diptangsu', 'AOT'

# %%
print('x =', x)
print('y =', y)
print('z =', z)
print('name =', name)
print('college =', college)
# Out:
# x = 10
# y = 20
# z = 30
# name = Diptangsu
# college = AOT

# %% [markdown]
# ### Swapping two values

# %%
a, b = 123, 456
print('a =', a)
print('b =', b)
# Out:
# a = 123
# b = 456

# %%
t = a
a = b
b = t
print('a =', a)
print('b =', b)
# Out:
# a = 456
# b = 123

# %% [markdown]
# ### Swapping two values (in python)

# %%
m, n = 20, 40
print('m =', m)
print('n =', n)

print('\nSwapping m and n')
m, n = n, m

print('m =', m)
print('n =', n)
# Out:
# m = 20
# n = 40
#
# Swapping m and n
# m = 40
# n = 20

# %% [markdown]
# ## A brief overview about what statically and dynamically typed mean

# %% [markdown]
# ### Statically typed
# - The types of variables are checked at compile time
# - The programmer must specify the type of every variable
#
#
# - A considerable amount of checks can be performed by the compiler
# - Reduces trivial bugs

# %% [markdown]
# ### Dynamically typed
# - The types of variables are deduced during run time
# - The programmer doesn't have to specify the types of variables
#
#
# - Enables a programmer to write code quicker

# %% [markdown]
# #### The types of variables can be changed

# %%
print(name)
print(age)
# Out:
# Diptangsu Goswami
# 21

# %%
name = 123
age = 'Twenty one years'

# %%
print(name)
print(age)
# Out:
# 123
# Twenty one years

# %% [markdown]
# <hr>

# %% [markdown]
# ## Mutiline statements

# %%
x = 10 + 20 \
    - 30 + 5

print(x)
# Out:
# 5

# %% [markdown]
# ## Multiple statements in the same line

# %%
x = 10; y = 20; print(x, y)
# Out:
# 10 20

# %% [markdown]
# ***

# %% [markdown]
# ## Keywords
# - used to define the syntax and structure of the language
# - case sensitive
# - cannot be used as variable names, function names or any other identifier

# %%
from keyword import kwlist

print(f'Python3 has {len(kwlist)} keywords')
print()
print(kwlist)
# Out:
# Python3 has 35 keywords
#
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
keywords = '\n'.join(['{:<10} {:<10} {:<10} {:<10} {:<10}'.format(*kwlist[i:i+5]) for i in range(0, len(kwlist), 5)])
print(keywords)
# Out:
# False      None       True       and        as
# assert     async      await      break      class
# continue   def        del        elif       else
# except     finally    for        from       global
# if         import     in         is         lambda
# nonlocal   not        or         pass       raise
# return     try        while      with       yield

# %% [markdown]
# ---

# %% [markdown]
# ## User input in Python3
#
# #### All input taken from the user is in the form of strings (str)

# %%
value = input('Enter a value : ')
# Out:
# Enter a value : here is a value

# %%
value
# Out:
# 'here is a value'

# %%
a = input('Enter a number : ')
b = input('Enter another number : ')
# Out:
# Enter a number : 123
# Enter another number : 239

# %%
a + b
# Out:
# '123239'

# %% [markdown]
# #### We will learn more about taking user input in the upcoming tutorials

# %% [markdown]
# ***

# %% [markdown]
# ## Python3 print() function extras

# %%
print(1000)
print(2000)
print('foo')
# Out:
# 1000
# 2000
# foo

# %%
print(1000, end='')
print(2000, end='')
print('foo')
# Out:
# 10002000foo

# %%
print(1000, end='#')
print(2000, end='@')
print('foo', end='bar')
# Out:
# 1000#2000@foobar

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %% [markdown]
# ***

# %% [markdown]
# ![questions.jpg](img/questions.jpg)
