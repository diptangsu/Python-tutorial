# %% [markdown]
# ## Numbers
# 	-> int
# 	-> float
# 	-> complex

# %% [markdown]
# ## Sequences
# 	-> list
# 	-> tuple
# 	-> str

# %% [markdown]
# ## Sets
# 	-> set
# 	-> frozenset

# %% [markdown]
# ## Mappings
# 	-> dict
# (key value pairs)

# %% [markdown]
# ## Boolean
# 	-> bool

# %% [markdown]
# ## None type
#     -> None

# %% [markdown]
# ***

# %% [markdown]
# ![questions.jpg](img/questions.jpg)
